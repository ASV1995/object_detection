# %% [markdown]
# ### Virtual Environment

# %%
# python -m venv objd
# .\objd\Scripts\activate
# python.exe -m pip install --upgrade pip
# pip install ipykernel
# python -m ipykernel install --user --name=objd

# %%
# !pip list

# %% [markdown]
# ### Download Dependencies

# %%
# !pip install numpy
# !pip install matplotlib
# !pip install opencv-python
# !pip install jupyter_contrib_nbextensions ### Very important! -> Hinterland!!!
# !pip install labelImg
# !pip install pandas

# %%
# In command prompt type "LabelImg" and label all your collected images.

# %%
# In command prompt type "jupyter notebook" to start coding.

# %% [markdown]
# ### Download Dependencies

# %%
import os
from glob import glob
import pandas as pd
import matplotlib.pyplot as plt
from functools import reduce
from xml.etree import ElementTree as et # Python library that allows you to parse and navigate an XML document.

# %% [markdown]
# ### Begin Filename Extraction

# %%
import os

def get_xml_paths(directory_path):
    xml_paths = [] # Create an empty list.
    xml_names = os.listdir(directory_path) # Get all the filenames inside filepath.

    for xml_name in xml_names:
        if xml_name.endswith(".xml"): # After for loop if filename ends in .xml [Very important]!
            xml_path = os.path.join(directory_path, xml_name) # Join filename with file directory.
            xml_paths.append(xml_path) # Finally append to list.

    return xml_paths

directory_path = r'C:\Users\15149\Desktop\Data Science Projects\Object Detection - Jupyter Notebook\objd\Data_Images'

xml_paths_list = get_xml_paths(directory_path)

# %%
xml_paths_list[:5]
# Out:
# ['C:\\Users\\15149\\Desktop\\Data Science Projects\\Object Detection - Jupyter Notebook\\objd\\Data_Images\\fork.4bbdabfe-7fd2-11ee-9863-a683e7398f45.xml',
#  'C:\\Users\\15149\\Desktop\\Data Science Projects\\Object Detection - Jupyter Notebook\\objd\\Data_Images\\fork.4cf456a8-7fd2-11ee-9863-a683e7398f45.xml',
#  'C:\\Users\\15149\\Desktop\\Data Science Projects\\Object Detection - Jupyter Notebook\\objd\\Data_Images\\fork.4e2fefd2-7fd2-11ee-9863-a683e7398f45.xml',
#  'C:\\Users\\15149\\Desktop\\Data Science Projects\\Object Detection - Jupyter Notebook\\objd\\Data_Images\\fork.4f6a43fc-7fd2-11ee-9863-a683e7398f45.xml',
#  'C:\\Users\\15149\\Desktop\\Data Science Projects\\Object Detection - Jupyter Notebook\\objd\\Data_Images\\fork.50a5b76a-7fd2-11ee-9863-a683e7398f45.xml']

# %%
# Read xml files.

def extract_xml_pics(filename):
    parse_tree = et.parse(filename) # Finds the fileman of each xml file in xml_paths_list
    get_root = parse_tree.getroot() #  Returns the root component of this path as a Path object.

# Extract all nessessary information from .xml image.
    image_name = get_root.find('filename').text
    get_width = get_root.find('size').find('width').text
    get_height = get_root.find('size').find('height').text
    
    find_objects = get_root.findall('object') # As we have multiple elements with "objects" so use findall then we need to find what we are looking for.

    parser = []
    for object in find_objects:
        get_name = object.find('name').text # Image name
        get_bndbox = object.find('bndbox') # Bound box [] of image after using labelImg
        get_xmin = get_bndbox.find('xmin').text # Xmin of bound box
        get_xmax = get_bndbox.find('xmax').text # Xmax of bound box
        get_ymin = get_bndbox.find('ymin').text # Ymin of bound box
        get_ymax = get_bndbox.find('ymax').text # Ymax of bound box
        parser.append([image_name, get_width, get_height, get_name, get_xmin, get_xmax, get_ymin, get_ymax])
    return parser

# %%
parser_all_xml = list(map(extract_xml_pics, xml_paths_list))

# %%
data = reduce(lambda x, y: x+y, parser_all_xml)

# %% [markdown]
# ### Create XML information dataframe

# %%
df = pd.DataFrame(data, columns = ['Filename','Width','Height','Name','Xmin','Xmax','Ymin','Ymax'])
df.head()
# Out:
#                                         Filename Width Height  Name Xmin Xmax  \
# 0  fork.4bbdabfe-7fd2-11ee-9863-a683e7398f45.jpg  1280    720  fork  216  878
# 1  fork.4cf456a8-7fd2-11ee-9863-a683e7398f45.jpg  1280    720  fork  463  595
# 2  fork.4e2fefd2-7fd2-11ee-9863-a683e7398f45.jpg  1280    720  fork  186  831
# 3  fork.4f6a43fc-7fd2-11ee-9863-a683e7398f45.jpg  1280    720  fork  418  583
# 4  fork.50a5b76a-7fd2-11ee-9863-a683e7398f45.jpg  1280    720  fork  314  440
#
#   Ymin Ymax
# 0   79  292
# 1   43  343
# 2  121  286
# 3    1  426
# 4   77  490

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Filename  20 non-null     object
#  1   Width     20 non-null     int64
#  2   Height    20 non-null     int64
#  3   Name      20 non-null     object
#  4   Xmin      20 non-null     int64
#  5   Xmax      20 non-null     int64
#  6   Ymin      20 non-null     int64
#  7   Ymax      20 non-null     int64
# dtypes: int64(6), object(2)
# memory usage: 1.4+ KB

# %%
df.shape # 20 rows and 8 columns
# Out:
# (20, 8)

# %%
cols = ['Width','Height', 'Xmin', 'Xmax', 'Ymin', 'Ymax']
df[cols] = df[cols].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Filename  20 non-null     object
#  1   Width     20 non-null     int32
#  2   Height    20 non-null     int32
#  3   Name      20 non-null     object
#  4   Xmin      20 non-null     int32
#  5   Xmax      20 non-null     int32
#  6   Ymin      20 non-null     int32
#  7   Ymax      20 non-null     int32
# dtypes: int32(6), object(2)
# memory usage: 932.0+ bytes

# %% [markdown]
# ### Find Center X and Center Y of Image

# %%
df['center_X'] = ((df['Xmax'])+df['Xmin'])/2/df['Width']
df['center_Y'] = ((df['Ymax'])+df['Ymin'])/2/df['Height']

# %% [markdown]
# ### Find Height and Weight of Image

# %%
df['W'] = ((df['Xmax'])-df['Xmin'])/df['Width']
df['H'] = ((df['Ymax'])-df['Ymin'])/df['Height']

# %%
df.head()
# Out:
#                                         Filename  Width  Height  Name  Xmin  \
# 0  fork.4bbdabfe-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   216
# 1  fork.4cf456a8-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   463
# 2  fork.4e2fefd2-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   186
# 3  fork.4f6a43fc-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   418
# 4  fork.50a5b76a-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   314
#
#    Xmax  Ymin  Ymax  center_X  center_Y         W         H
# 0   878    79   292  0.427344  0.257639  0.517188  0.295833
# 1   595    43   343  0.413281  0.268056  0.103125  0.416667
# 2   831   121   286  0.397266  0.282639  0.503906  0.229167
# 3   583     1   426  0.391016  0.296528  0.128906  0.590278
# 4   440    77   490  0.294531  0.393750  0.098437  0.573611

# %%
x = df['Name']
x.unique()
# Out:
# array(['fork', 'glasses', 'knife', 'spoon'], dtype=object)

# %%
new_data_map = {'fork': 0, 'glasses': 1, 'knife': 2, 'spoon': 3, }
df['ID'] = df['Name'].map(new_data_map)

# %%
df.head()
# Out:
#                                         Filename  Width  Height  Name  Xmin  \
# 0  fork.4bbdabfe-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   216
# 1  fork.4cf456a8-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   463
# 2  fork.4e2fefd2-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   186
# 3  fork.4f6a43fc-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   418
# 4  fork.50a5b76a-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  fork   314
#
#    Xmax  Ymin  Ymax  center_X  center_Y         W         H  ID
# 0   878    79   292  0.427344  0.257639  0.517188  0.295833   0
# 1   595    43   343  0.413281  0.268056  0.103125  0.416667   0
# 2   831   121   286  0.397266  0.282639  0.503906  0.229167   0
# 3   583     1   426  0.391016  0.296528  0.128906  0.590278   0
# 4   440    77   490  0.294531  0.393750  0.098437  0.573611   0

# %%
df = df.to_csv('objd_data.csv', index = False) # Save dataframe for later use.

# %% [markdown]
# ### Train Test Split

# %%
df = pd.read_csv('objd_data.csv')

# %%
# !pip install -U scikit-learn scipy matplotlib

# %%
from sklearn.model_selection import train_test_split

# %%
df
# Out:
#                                             Filename  Width  Height     Name  \
# 0      fork.4bbdabfe-7fd2-11ee-9863-a683e7398f45.jpg   1280     720     fork
# 1      fork.4cf456a8-7fd2-11ee-9863-a683e7398f45.jpg   1280     720     fork
# 2      fork.4e2fefd2-7fd2-11ee-9863-a683e7398f45.jpg   1280     720     fork
# 3      fork.4f6a43fc-7fd2-11ee-9863-a683e7398f45.jpg   1280     720     fork
# 4      fork.50a5b76a-7fd2-11ee-9863-a683e7398f45.jpg   1280     720     fork
# 5   glasses.5e0d1b96-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 6   glasses.5f48a750-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 7   glasses.6083e81e-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 8   glasses.61bf9eda-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 9   glasses.62fad166-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 10    knife.54e65b7c-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 11    knife.5620bf3c-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 12    knife.57585310-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 13    knife.58922008-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 14    knife.59c888e0-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 15    spoon.428c81ea-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    spoon
# 16    spoon.43ccb14c-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    spoon
# 17    spoon.45076a0c-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    spoon
# 18    spoon.464240ea-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    spoon
# 19    spoon.477a610e-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    spoon
#
#     Xmin  Xmax  Ymin  Ymax  center_X  center_Y         W         H  ID
# 0    216   878    79   292  0.427344  0.257639  0.517188  0.295833   0
# 1    463   595    43   343  0.413281  0.268056  0.103125  0.416667   0
# 2    186   831   121   286  0.397266  0.282639  0.503906  0.229167   0
# 3    418   583     1   426  0.391016  0.296528  0.128906  0.590278   0
# 4    314   440    77   490  0.294531  0.393750  0.098437  0.573611   0
# 5    264   760     9   271  0.400000  0.194444  0.387500  0.363889   1
# 6    181   683     4   291  0.337500  0.204861  0.392188  0.398611   1
# 7    182   682     3   287  0.337500  0.201389  0.390625  0.394444   1
# 8    234   701     5   340  0.365234  0.239583  0.364844  0.465278   1
# 9    235   699     4   342  0.364844  0.240278  0.362500  0.469444   1
# 10   344   531     1   338  0.341797  0.235417  0.146094  0.468056   2
# 11   347   533     1   338  0.343750  0.235417  0.145313  0.468056   2
# 12    29   721    74   273  0.292969  0.240972  0.540625  0.276389   2
# 13   385   469     1   370  0.333594  0.257639  0.065625  0.512500   2
# 14   166   885   149   217  0.410547  0.254167  0.561719  0.094444   2
# 15   120   835   144   264  0.373047  0.283333  0.558594  0.166667   3
# 16   437   599    40   360  0.404687  0.277778  0.126562  0.444444   3
# 17   434   601   199   365  0.404297  0.391667  0.130469  0.230556   3
# 18   151   891   162   273  0.407031  0.302083  0.578125  0.154167   3
# 19   438   579     1   440  0.397266  0.306250  0.110156  0.609722   3

# %%
train, test = train_test_split(df, test_size=0.2, random_state = 42)

# %%
print(f'The train = {len(train) / (len(train) + len(test)) * 100}%')
print(f'The test = {len(test) / (len(train) + len(test)) * 100}%')
# Out:
# The train = 80.0%
# The test = 20.0%

# %%
train
# Out:
#                                             Filename  Width  Height     Name  \
# 8   glasses.61bf9eda-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 5   glasses.5e0d1b96-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 11    knife.5620bf3c-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 3      fork.4f6a43fc-7fd2-11ee-9863-a683e7398f45.jpg   1280     720     fork
# 18    spoon.464240ea-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    spoon
# 16    spoon.43ccb14c-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    spoon
# 13    knife.58922008-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 2      fork.4e2fefd2-7fd2-11ee-9863-a683e7398f45.jpg   1280     720     fork
# 9   glasses.62fad166-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 19    spoon.477a610e-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    spoon
# 4      fork.50a5b76a-7fd2-11ee-9863-a683e7398f45.jpg   1280     720     fork
# 12    knife.57585310-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 7   glasses.6083e81e-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
# 10    knife.54e65b7c-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 14    knife.59c888e0-7fd2-11ee-9863-a683e7398f45.jpg   1280     720    knife
# 6   glasses.5f48a750-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  glasses
#
#     Xmin  Xmax  Ymin  Ymax  center_X  center_Y         W         H  ID
# 8    234   701     5   340  0.365234  0.239583  0.364844  0.465278   1
# 5    264   760     9   271  0.400000  0.194444  0.387500  0.363889   1
# 11   347   533     1   338  0.343750  0.235417  0.145313  0.468056   2
# 3    418   583     1   426  0.391016  0.296528  0.128906  0.590278   0
# 18   151   891   162   273  0.407031  0.302083  0.578125  0.154167   3
# 16   437   599    40   360  0.404687  0.277778  0.126562  0.444444   3
# 13   385   469     1   370  0.333594  0.257639  0.065625  0.512500   2
# 2    186   831   121   286  0.397266  0.282639  0.503906  0.229167   0
# 9    235   699     4   342  0.364844  0.240278  0.362500  0.469444   1
# 19   438   579     1   440  0.397266  0.306250  0.110156  0.609722   3
# 4    314   440    77   490  0.294531  0.393750  0.098437  0.573611   0
# 12    29   721    74   273  0.292969  0.240972  0.540625  0.276389   2
# 7    182   682     3   287  0.337500  0.201389  0.390625  0.394444   1
# 10   344   531     1   338  0.341797  0.235417  0.146094  0.468056   2
# 14   166   885   149   217  0.410547  0.254167  0.561719  0.094444   2
# 6    181   683     4   291  0.337500  0.204861  0.392188  0.398611   1

# %%
test
# Out:
#                                           Filename  Width  Height   Name  \
# 0    fork.4bbdabfe-7fd2-11ee-9863-a683e7398f45.jpg   1280     720   fork
# 17  spoon.45076a0c-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  spoon
# 15  spoon.428c81ea-7fd2-11ee-9863-a683e7398f45.jpg   1280     720  spoon
# 1    fork.4cf456a8-7fd2-11ee-9863-a683e7398f45.jpg   1280     720   fork
#
#     Xmin  Xmax  Ymin  Ymax  center_X  center_Y         W         H  ID
# 0    216   878    79   292  0.427344  0.257639  0.517188  0.295833   0
# 17   434   601   199   365  0.404297  0.391667  0.130469  0.230556   3
# 15   120   835   144   264  0.373047  0.283333  0.558594  0.166667   3
# 1    463   595    43   343  0.413281  0.268056  0.103125  0.416667   0

# %% [markdown]
# ### Folder Creation and Image Storage

# %%
from shutil import move

# %%
train_folder = r'C:\Users\15149\Desktop\Data Science Projects\Object Detection - Jupyter Notebook\objd\Data_Images\Train'
test_folder = r'C:\Users\15149\Desktop\Data Science Projects\Object Detection - Jupyter Notebook\objd\Data_Images\Test'

# %%
os.mkdir(train_folder)
os.mkdir(test_folder)

# %%
cols = ['Filename','ID','center_X','center_Y','W','H']
groupby_obj_train = train[cols].groupby('Filename')
groupby_obj_test = test[cols].groupby('Filename')

# %%
def save_data(filename, folder_path, groupby_obj):
    source = os.path.join('Data_Images', filename)
    destination = os.path.join(folder_path, filename)
    move(source, destination)

    text_filename = os.path.join(folder_path, 
                                 os.path.splitext(filename)[0]+'.txt')
    groupby_obj.get_group(filename).set_index('Filename').to_csv(text_filename, sep=' ', index=False, header=False)

# %%
filename_series = pd.Series(groupby_obj_train.groups.keys())
filename_series.apply(save_data, args=(train_folder, groupby_obj_train))
# Out:
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# 15    None
# dtype: object

# %% [markdown]
# I seem to have a clash with my folders resulting in an error I am not only don't understand but also too tired to figure out today.

# %%
filename_series = pd.Series(groupby_obj_test.groups.keys())
filename_series.apply(save_data, args=(test_folder, groupby_obj_test))
# Out:
# 0    None
# 1    None
# 2    None
# 3    None
# dtype: object

# %% [markdown]
# Save the .XML files into a new folder called 'Annotations'
